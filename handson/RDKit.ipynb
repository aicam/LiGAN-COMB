# %% [markdown]
# # Input preparing
# This tutorial explains the Molecule class in the library which provides the functionalities to prepare the input data to deep learning model

# %% [markdown]
# # Preparing input data

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
# !curl -Lo conda_installer.py https://raw.githubusercontent.com/deepchem/deepchem/master/scripts/colab_install.py
import conda_installer
import matplotlib.pyplot as plt
# conda_installer.install()
conda_installer.install()
# !/root/miniconda/bin/conda info -e
from rdkit import Chem
# Out:
# 2023-02-25 16:04:39.532753: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-25 16:04:39.532768: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# add /home/ali/miniconda/lib/python3.8/site-packages to PYTHONPATH
# all packages are already installed

# %%
# read the pdb
mol = Chem.MolFromPDBFile('BRD4.pdb')

# %%
# display the mol
mol

# %% [markdown]
# # Molecule class
# ## the following cells explain methods included in Molecule class
# ## in each cell copy the method from the class to the cell

# %%
# use from_pdb method of class to get the mol from pdb

def read_rd_mol_from_pdb_file(pdb_file, sanitize=True):
    return Chem.MolFromPDBFile(pdb_file, sanitize=sanitize)
def from_pdb(pdb_file,sanitize=True):
    mol = read_rd_mol_from_pdb_file(pdb_file, sanitize=sanitize)
    return mol

# %%
# test the method
mol = from_pdb('BRD4.pdb')
mol

# %%
# use to_smi method of class to get the smile of mol
def get_smiles_string(rd_mol):
    return Chem.MolToSmiles(rd_mol, canonical=True, isomericSmiles=False)
## TODO: copy and test the method

# %%
# test the method

# %%
# use n_hydros method and explain the input and output of the method

# %%
# test the method

# %%
# use bonds method and explain the input and output of the method

# %%
# test the method

# %%
# use translate method and explain the input and output of the method

# %%
# test the method
